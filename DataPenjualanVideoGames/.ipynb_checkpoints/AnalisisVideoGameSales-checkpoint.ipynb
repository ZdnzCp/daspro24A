# %%
import pandas as pd

df = pd.read_csv('vgsales.csv')
data = df[['JP_Sales', 'Global_Sales']].dropna()

# %%
print("Statistik JP_Sales:")
print(data['JP_Sales'].describe())

print("\nStatistik Global_Sales:")
print(data['Global_Sales'].describe())
# Out:
# Statistik JP_Sales:
# count    16598.000000
# mean         0.077782
# std          0.309291
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: JP_Sales, dtype: float64
#
# Statistik Global_Sales:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

X = data[['JP_Sales']]
Y = data[['Global_Sales']]

model = LinearRegression()
model.fit(X, y)

print(f"Intercept: {model.intercept_}")
print(f"Koefisien: {model.coef_[0]}")
print(f"R^2 Score: {model.score(X, y)}")
# Out:
# Intercept: 0.29818120273378335
# Koefisien: 3.076039408393878
# R^2 Score: 0.3743182282571035

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.scatterplot(x='JP_Sales', y='Global_Sales', data=data, color='green', alpha=0.5)
plt.plot(X, model.predict(X), color='red')
plt.title('JP_Sales vs Global_Sales')
plt.xlabel('Penjualan di Jepang (Juta Unit)')
plt.ylabel('Penjualan Global (Juta Unit)')
plt.grid(True)
plt.show()
